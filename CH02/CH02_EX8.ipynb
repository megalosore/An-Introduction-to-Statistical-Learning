# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import ISLP

# %%
college = pd.read_csv("../../DATA/College.csv", index_col=0)

# %%
college.describe().astype('int')
# Out:
#         Apps  Accept  Enroll  Top10perc  Top25perc  F.Undergrad  P.Undergrad  \
# count    777     777     777        777        777          777          777
# mean    3001    2018     779         27         55         3699          855
# std     3870    2451     929         17         19         4850         1522
# min       81      72      35          1          9          139            1
# 25%      776     604     242         15         41          992           95
# 50%     1558    1110     434         23         54         1707          353
# 75%     3624    2424     902         35         69         4005          967
# max    48094   26330    6392         96        100        31643        21836
#
#        Outstate  Room.Board  Books  Personal  PhD  Terminal  S.F.Ratio  \
# count       777         777    777       777  777       777        777
# mean      10440        4357    549      1340   72        79         14
# ...

# %%
college[college["Grad.Rate"] > 100]
# Out:
#                   Private  Apps  Accept  Enroll  Top10perc  Top25perc  \
# College
# Cazenovia College     Yes  3847    3433     527          9         35
#
#                    F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  \
# College
# Cazenovia College         1010           12      9384        4840    600
#
#                    Personal  PhD  Terminal  S.F.Ratio  perc.alumni  Expend  \
# College
# Cazenovia College       500   22        47       14.3           20    7697
#
#                    Grad.Rate
# College
# Cazenovia College        118

# %%
pd.plotting.scatter_matrix(college[['Top10perc', 'Apps', 'Enroll']]);

# %%
college[['Outstate', 'Private']].boxplot(by='Private')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='[Private]'>

# %%
college['Elite'] = pd.cut(college['Top10perc'], bins=2, labels =['No', 'Yes'])

# %%
college['Elite'].value_counts()
# Out:
# Elite
# No     687
# Yes     90
# Name: count, dtype: int64

# %%
college[['Outstate', 'Elite']].boxplot(by='Elite')
# Out:
# <Axes: title={'center': 'Outstate'}, xlabel='[Elite]'>

# %%
college[['Elite', 'Private']].value_counts()[2:4].plot.bar()
# Out:
# <Axes: xlabel='Elite,Private'>

# %%
pd.plotting.scatter_matrix(college, diagonal='kde', figsize=(20,20));
