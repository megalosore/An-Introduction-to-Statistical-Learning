# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots
import statsmodels.api as sm
from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
                         summarize)
from ISLP import confusion_table
from ISLP.models import contrast
from sklearn.discriminant_analysis import \
     (LinearDiscriminantAnalysis as LDA,
      QuadraticDiscriminantAnalysis as QDA)
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import seaborn as sns

# %%
default = load_data("Default")

# %%
raw_X = default[["income","balance"]]
y = default["default"].transform(lambda x : x == "Yes")

# %%
design = MS(['income', 'balance'])
X = design.fit_transform(raw_X)

# %%
model = sm.Logit(y, X).fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.078948
#          Iterations 10

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                default   No. Observations:                10000
# Model:                          Logit   Df Residuals:                     9997
# Method:                           MLE   Df Model:                            2
# Date:                Tue, 02 Sep 2025   Pseudo R-squ.:                  0.4594
# Time:                        22:18:10   Log-Likelihood:                -789.48
# converged:                       True   LL-Null:                       -1460.3
# Covariance Type:            nonrobust   LLR p-value:                4.541e-292
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept    -11.5405      0.435    -26.544      0.000     -12.393     -10.688
# income      2.081e-05   4.99e-06      4.174      0.000     1.1e-05    3.06e-05
# balance        0.0056      0.000     24.835      0.000       0.005       0.006
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.14 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """

# %%
def boot_fn(df, idx):
    bootstraped = df.iloc[idx]
    raw_X = bootstraped[["income","balance"]]
    y = bootstraped["default"].transform(lambda x : x == "Yes")
    design = MS(['income', 'balance'])
    X = design.fit_transform(raw_X)
    model = sm.Logit(y, X).fit()
    return model.params[1:]

# %%
def gen_bootstrap(dataset, n=None, seed=42):
    n = len(dataset) if n == None else n
    rng = np.random.default_rng(seed)
    idx = rng.choice(dataset.index, n, replace=True)
    return idx

# %%
params = []
for i in range(100):
    idx = gen_bootstrap(default, seed=i)
    try:
        param = boot_fn(default, idx)
        params.append(param)
    except:
        pass
# Out:
# Optimization terminated successfully.
#          Current function value: 0.075669
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078323
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073743
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075895
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083063
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075904
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076002
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074152
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073475
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.086807
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073950
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080236
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080434
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.072985
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081721
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077189
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077301
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078987
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076240
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081237
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078154
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.072377
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.071470
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.085045
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080835
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.084550
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075255
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075414
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.072412
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077768
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081732
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075708
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076470
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080386
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077037
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081037
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073194
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081001
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076963
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075854
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074154
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076033
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077412
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080070
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.085194
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.088396
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078730
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081124
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077517
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082066
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078903
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.084982
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077099
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078257
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075419
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078528
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.072165
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083840
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078998
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080726
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077627
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080086
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075682
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.070895
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079980
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079845
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.072952
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076151
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.085330
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078087
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079535
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082935
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077004
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080325
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078145
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076632
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.080597
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.073910
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074012
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078194
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077918
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074196
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.081608
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082562
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076272
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.077706
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079789
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.074510
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.076721
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.078199
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075330
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079633
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083689
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.083281
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.079987
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.084785
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.084070
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.075589
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.085032
#          Iterations 10
# Optimization terminated successfully.
#          Current function value: 0.082412
#          Iterations 10

# %%
len(params), np.mean(params, axis=0), np.std(params, axis=0)
# Out:
# (100,
#  array([2.11433136e-05, 5.66866101e-03]),
#  array([4.85114196e-06, 2.33184818e-04]))

# %%
# Pretty similar :
# 4.99e-06 vs 4.85114196e-06
# 0.000 vs 2.33184818e-04
